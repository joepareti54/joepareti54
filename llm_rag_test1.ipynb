# %% [markdown]
# <a href="https://colab.research.google.com/github/joepareti54/joepareti54/blob/main/llm_rag_test1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pymupdf
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.0/20.0 MB 71.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

import fitz  # Import PyMuPDF
import os

# Directory containing PDFs
directory_path = '/content/drive/My Drive/All_Finance_PDF_files_old/'

# Iterate over all files in the directory
for filename in os.listdir(directory_path):
    if filename.endswith('.pdf'):  # Check if the file is a PDF
        pdf_path = os.path.join(directory_path, filename)
        doc = fitz.open(pdf_path)
        print(f"Processing '{filename}' with {len(doc)} pages.")  # Print filename and page count
        doc.close()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# Processing 'China’s Covid-19 Surge Shuts Down Plants in Manufacturing Hubs Shenzhen and Changchun - WSJ.pdf' with 6 pages.
# Processing 'Russian Prosecutors Warn Western Companies of Arrests, Asset Seizures - WSJ.pdf' with 7 pages.
# Processing 'Können russische Oligarchen Sanktionen mit Kryptowährungen umgehen.pdf' with 7 pages.
# Processing 'TikTok Influencers Get Spotlight in Information Battle Over the Russia-Ukraine War - WSJ.pdf' with 8 pages.
# Processing 'Chip Makers Stockpiled Key Materials Ahead of Russian Invasion of Ukraine - WSJ.pdf' with 7 pages.
# Processing 'Western Drugmakers Are Still Providing Medicines to Russia - WSJ.pdf' with 7 pages.
# Processing 'China Leads the Way With Private 5G Networks at Industrial Facilities - WSJ.pdf' with 3 pages.
# ...
